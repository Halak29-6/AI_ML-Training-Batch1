# %% [markdown]
# <a href="https://colab.research.google.com/github/Halak29-6/AI_ML-Training-Batch1/blob/main/Homework/seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Basics of seaborn and EDA & Rest of all functions of line plot and the displot , histplot.

# %%
import seaborn as sns

# %%
dataset = sns.get_dataset_names()

# %%
print(dataset)
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
sns.load_dataset('tips')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df = sns.load_dataset('tips')

# %%
sns.lineplot(x='total_bill', y='tip', data=df , color='r')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.lineplot(x='total_bill', y='tip', data=df  )
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(x=df['tip'], y = df['day'], data = df , color = 'g' , hue='size')
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
t_df = sns.load_dataset('titanic')
print(t_df)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.lineplot(x = tdf['sex'] , y = tdf['survived'] , data = tdf , color = 'b',hue='class' )
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
sns.lineplot(x='embark_town' , y='alive' , data=tdf , color='r' ,hue='fare')
# Out:
# <Axes: xlabel='embark_town', ylabel='alive'>

# %%
sns.displot(x='pclass' ,data=tdf)

# %%
sns.histplot(x='age' ,  data=tdf ,color='g')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.distplot(x=df['tip'], rug=True )
# Out:
# /tmp/ipykernel_4403/3895207746.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['tip'], rug=True )
# <Axes: ylabel='Density'>

# %%
sort dup value , value count  , description , size shape , on car_crashes
# Out:
#   File "/tmp/ipykernel_4403/4185521724.py", line 1
#     sort dup value , value count  , description , size shape , on car_crashes
#          ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
dff = sns.load_dataset('car_crashes')
#perform data distribution
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %%
dff.describe()
# Out:
#            total   speeding    alcohol  not_distracted  no_previous  \
# count  51.000000  51.000000  51.000000       51.000000    51.000000
# mean   15.790196   4.998196   4.886784       13.573176    14.004882
# std     4.122002   2.017747   1.729133        4.508977     3.764672
# min     5.900000   1.792000   1.593000        1.760000     5.900000
# 25%    12.750000   3.766500   3.894000       10.478000    11.348000
# 50%    15.600000   4.608000   4.554000       13.857000    13.775000
# 75%    18.500000   6.439000   5.604000       16.140000    16.755000
# max    23.900000   9.450000  10.038000       23.661000    21.280000
#
#        ins_premium  ins_losses
# count    51.000000   51.000000
# mean    886.957647  134.493137
# std     178.296285   24.835922
# min     641.960000   82.750000
# 25%     768.430000  114.645000
# 50%     858.970000  136.050000
# 75%    1007.945000  151.870000
# max    1301.520000  194.780000

# %%
dff.size
# Out:
# 408

# %%
dff.shape
# Out:
# (51, 8)

# %%
dff.dtypes
# Out:
# total             float64
# speeding          float64
# alcohol           float64
# not_distracted    float64
# no_previous       float64
# ins_premium       float64
# ins_losses        float64
# abbrev             object
# dtype: object

# %%
dff.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
dff.duplicated().sum()
# Out:
# np.int64(0)

# %%
dff.sort_values( by='speeding' , ascending=True)
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 30   11.2     1.792    3.136           9.632        8.736      1301.52
# 21    8.2     1.886    2.870           7.134        6.560      1011.14
# 27   14.9     1.937    5.215          13.857       13.410       732.28
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 23    9.6     2.208    2.784           8.448        8.448       777.18
# 46   12.7     2.413    3.429          11.049       11.176       768.95
# 24   17.6     2.640    5.456           1.760       17.600       896.07
# 15   15.7     2.669    3.925          15.229       13.659       649.06
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 22   14.1     3.384    3.948          13.395       10.857      1110.61
# 31   18.4     3.496    4.968          12.328       18.032       869.85
# 14   14.5     3.625    4.205          13.775       13.775       710.46
# ...
